# %% [markdown]
# # **Objective:**
#
# *   Anak perusahaan PT Taspen (persero) yaitu PT Taspen Property akan membangun sebuah apartemen beranama Aspena Residence, Proyek pembangunan apartemen 612 unit, berlokasi di daerah Jalan Daan Mogot, Tangerang. Apartemen ini menawarkan kehidupan nyaman di tengah kota dengan akses strategis dekat dengan stasiun batu ceper, Bandara Soekarno Hatta, dan pemerintahan daerah. Apartemen ini diprioritaskan untuk Aparatur Sipil Negara (ASN), BUMN dan masyarakat yang membutuhkannya untuk tempat tinggal dan investasi.
#
# *   Maka dari itu perlu pendalaman data untuk memvalidasi serta menemukan potensi dan strategi pemasaran yang efektif, yaitu :
# >1.   Validasi potensi market yang ada pada daerah pembangunan dan daerah sekitar yang masih masuk dalam wilayah target market
# >2.   Apakah Target market memiliki daya beli yang sejalan dengan harga dari apartemen yang akan dibangun
# >3.   Menemukan potensi customer segmentation yang nantinya akan dijadikan dasar rencana strategis pemasaran oleh tim bisnis
#
#
# # **About organization:**
#
# *   *PT TASPEN (Persero)* or Civil Service Savings and Insurance Fund is an Indonesian State-Owned Enterprise which is engaged in old-age savings insurance and pension funds for ASN and State Officials.
#
# *  *PT Taspen Properti Indonesia* yang sebelumnya bernama PT Arthaloka Indonesia berdiri pada bulan April tahun 1988, di mana sahamnya dimiliki oleh T Taspen (Persero) dan Pemegang Saham lainnya. Saat ini menjalankan bisnis sebagai pengelola gedung Menara Taspen, pengembang pembangunan Apartemen di Batu Ceper Tangerang, serta pembangunan Gedung Iconic di Jalan Jenderal Sudirman

# %% [markdown]
# # **Variable Description**
#
# >*   **ID** :unique id peserta.
# >*   **NAMA_STATUS_PEGAWAI** : status PNS
# >*   **NAMA_STATUS_KAWIN** : status perkawinan
# >*   **TAHUN_LAHIR** : tahun lahir peserta
# >*   **JENIS_KELAMIN** : jenis kelamin
# >*   **JMLISTRI** : jumlah istri
# >*   **JMLANAK** : jumlah anak
# >*   **THP** : Take home pay (Gapok + Tukin + Tujab)
# >*   **TMT_KERJA** : Tahun masuk menjadi PNS
# >*   **BUP** : Batas usia pensiun
# >*   **NAMA_SATKER** : nama satuan kerja
# >*   **NAMA_DATI2** : daerah

# %%
### Data Analysis and Manipulation 
import pandas as pd
import numpy as np

### Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set() ## this is for styling

### Data Standardization and Modeling with K-Means and PCA
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
# import data dari csv
df = pd.read_csv('./sample_data/data_peserta_fixs.csv')
df.head()
# Out:
#                          ID_PESERTA NAMA_STATUS_PEGAWAI NAMA_STATUS_KAWIN  \
# 0  D7F1E7316F97425C1700B06CFB291994       PEGAWAI TETAP             NIKAH
# 1  3562F7316F97425C1700B06CFB291994       PEGAWAI TETAP             NIKAH
# 2  529BE2316F97425C1700B06CFB291994       PEGAWAI TETAP             NIKAH
# 3  38EAEF316F97425C1700B06CFB291994       PEGAWAI TETAP            LAJANG
# 4  7748ED316F97425C1700B06CFB291994       PEGAWAI TETAP            LAJANG
#
#    TAHUN_LAHIR JENIS_KELAMIN  JMLISTRI  JMLANAK      THP   TMT_KERJA  BUP  \
# 0         1965             P         1        0  4959460  1985-03-01   58
# 1         1973             P         1        2  4311936  2007-01-01   60
# 2         1982             P         1        2  3769410  2009-06-01   58
# 3         1980             P         1        1  3702384  2006-04-01   58
# 4         1965             L         0        0  3628900  2010-01-01   60
#
#                                          NAMA_SATKER     NAMA_DATI2  \
# 0                       PUSKESMAS PAMATANG SIDAMANIK    DKI JAKARTA
# 1                         BLUD PUSKESMAS PASAR KEMIS  JAKARTA TIMUR
# 2                                 PUSKESMAS BATUYANG  JAKARTA TIMUR
# 3                   PUSKESMAS KECAMATAN RANTAU RASAU  JAKARTA BARAT
# 4  DINAS KESEHATAN KAB PEMALANG (PUSKESMAS KEBAND...      KAB BOGOR
#
#   KODE_PANGKAT
# 0           3D
# 1           4A
# 2           3D
# 3           3A
# 4           3D

# %%
print(f'Total data awal yang digunakan sebanyak {len(df)}')
# Out:
# Total data awal yang digunakan sebanyak 210216

# %%
# show overall info dari data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210216 entries, 0 to 210215
# Data columns (total 13 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID_PESERTA           210216 non-null  object
#  1   NAMA_STATUS_PEGAWAI  210216 non-null  object
#  2   NAMA_STATUS_KAWIN    210216 non-null  object
#  3   TAHUN_LAHIR          210216 non-null  int64
#  4   JENIS_KELAMIN        210216 non-null  object
#  5   JMLISTRI             210216 non-null  int64
#  6   JMLANAK              210216 non-null  int64
#  7   THP                  210216 non-null  int64
#  8   TMT_KERJA            210216 non-null  object
#  9   BUP                  210216 non-null  int64
#  10  NAMA_SATKER          210216 non-null  object
#  11  NAMA_DATI2           210216 non-null  object
#  12  KODE_PANGKAT         210216 non-null  object
# dtypes: int64(5), object(8)
# memory usage: 20.8+ MB

# %% [markdown]
# # Cleansing & Validating Data
#
# ---

# %%
# ubah tipe data TMT_KERJA dtype = object -> datetime
df['TMT_KERJA'] = pd.to_datetime(df['TMT_KERJA'])

# %%
df.describe()
# Out:
#          TAHUN_LAHIR       JMLISTRI        JMLANAK           THP  \
# count  210216.000000  210216.000000  210216.000000  2.102160e+05
# mean     1975.916519       0.760746       1.137506  3.892382e+06
# std         7.801004       0.426629       0.868066  5.401790e+05
# min      1936.000000       0.000000       0.000000  3.000000e+06
# 25%      1969.000000       1.000000       0.000000  3.442768e+06
# 50%      1976.000000       1.000000       1.000000  3.819872e+06
# 75%      1982.000000       1.000000       2.000000  4.310796e+06
# max      2001.000000       1.000000       3.000000  5.000000e+06
#
#                  BUP
# count  210216.000000
# mean       58.499748
# std         3.163503
# min         0.000000
# 25%        58.000000
# 50%        58.000000
# 75%        60.000000
# max        70.000000

# %%
# ANALISIS JENIS KELAMIN
genders = df.JENIS_KELAMIN.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(8,4))
sns.barplot(x=genders.index, y=genders.values)
plt.show()

# %%
# ANALISIS JMLISTRI
jmlistri = df.JMLISTRI.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(8,4))
sns.barplot(x=jmlistri.index, y=jmlistri.values)
plt.show()

# %%
# ANALISIS JUMLAH ANAK
jmlanak = df.JMLANAK.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(8,4))
sns.barplot(x=jmlanak.index, y=jmlanak.values)
plt.show()

# %%
# untuk memudahkan dan lebih jelas NAMA_DATI2 diganti ke DAERAH, dan THP (karena disini belum ada tukin dan tujab maka lebih baik diganti ke GAJI_POKOK)
df = df.rename(columns = {'NAMA_DATI2':'DAERAH', 'THP': 'GAJI_POKOK'})

# %%
# ANALISIS DAERAH
daerah = df.DAERAH.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(20,4))
sns.barplot(x=daerah.values, y=daerah.index)
plt.show()

# %%
# karena case yang akan di explore adalah pembangunan apartemen di daerah Tangerang, maka kita akan melihat deskripsi dari data PNS di sekitar jabodetabek
# cek dulu ada daerah apa saja
df.DAERAH.unique()
# Out:
# array(['DKI JAKARTA', 'JAKARTA TIMUR', 'JAKARTA BARAT', 'KAB BOGOR',
#        'JAKARTA', 'JAKARTA SELATAN', 'KOTA BEKASI', 'JAKARTA UTARA',
#        'BOGOR', 'DEPOK', 'BEKASI', 'KAB KARAWANG', 'TANGGERANG'],
#       dtype=object)

# %% [markdown]
# karena ada beberapa daerah yang sama tapi memiliki data yang ***berbeda*** maka data akan diupdate :
#
# >*   DKI JAKARTA -> JAKARTA PUSAT
# >*   KOTA BEKASI -> BEKASI
# >*   KAB BOGOR -> BOGOR
# >*   KAB KARAWANG -> KARAWANG

# %%
df.loc[df['DAERAH'] == 'DKI JAKARTA', 'DAERAH'] = 'JAKARTA PUSAT'
df.loc[df['DAERAH'] == 'KOTA BEKASI', 'DAERAH'] = 'BEKASI'
df.loc[df['DAERAH'] == 'KAB BOGOR', 'DAERAH'] = 'BOGOR'
df.loc[df['DAERAH'] == 'KAB KARAWANG', 'DAERAH'] = 'KARAWANG'

# %%
# ANALISIS DAERAH
daerah = df.DAERAH.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(20,4))
sns.barplot(x=daerah.values, y=daerah.index)
plt.show()

# %%
# ANALISIS BUP
bup = df.BUP.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(8,4))
sns.barplot(x=bup.index, y=bup.values)
plt.show()

# %%
#Change data BUP < 58 menjadi 58 karena PNS memiliki BUP mean 58 tahun
df.loc[df['BUP'] < 58, 'BUP'] = 58

# %%
bup = df.BUP.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(8,4))
sns.barplot(x=bup.index, y=bup.values)
plt.show()

# %%
# ANALISIS NAMA_STATUS_PEGAWAI
statuspegawai = df.NAMA_STATUS_PEGAWAI.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(10,4))
sns.barplot(x=statuspegawai.values, y=statuspegawai.index)
plt.show()

# %%
# dari data diatas masih ditemukan ada beberapa status pegawai yang kurang relevan, maka diputuskan untuk mengambil data PEGAWAI TETAP saja
df = df[df['NAMA_STATUS_PEGAWAI'] == 'PEGAWAI TETAP']

# %%
statuspegawai = df.NAMA_STATUS_PEGAWAI.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(10,4))
sns.barplot(x=statuspegawai.values, y=statuspegawai.index)
plt.show()

# %%
# ANALISIS NAMA_STATUS_KAWIN
statuskawin = df.NAMA_STATUS_KAWIN.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(8,4))
sns.barplot(x=statuskawin.index, y=statuskawin.values)
plt.show()

# %%
# ANALISIS KODE PANGKAT
kodepangkat = df.KODE_PANGKAT.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(10,4))
sns.barplot(x=kodepangkat.values, y=kodepangkat.index)
plt.show()

# %%
# ada beberapa kode pangkat khusus yang ada diluar kode pangkat ASN normal, kode pangkat PNS normal ada di range 1A - 4E
print(f"data yang memiliki kode pangkat diluar ASN sebanyak : {len(df[df['KODE_PANGKAT'].isin(['8A','7H','P3','8D','7D','09','7E','8E','6D','10','6I','7A','07','P5','P4'])])}")
# Out:
# data yang memiliki kode pangkat diluar ASN sebanyak : 2044

# %%
# exclude kode pangkat khusus
df = df[df['KODE_PANGKAT'].isin(['3D','4A','3A','2C','3B','2B','3C','4B','2A','2D','1D','4E','4D'])]
print(f'Jumlah data setelah cleansing : {len(df)}')
# Out:
# Jumlah data setelah cleansing : 204696

# %%
kodepangkat = df.KODE_PANGKAT.value_counts()
sns.set_style("darkgrid")
plt.figure(figsize=(10,4))
sns.barplot(x=kodepangkat.values, y=kodepangkat.index)
plt.show()

# %%
#Distribution of Tahun Lahir
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['TAHUN_LAHIR'])
plt.title('Distribution of Tahun Lahir', fontsize = 20)
plt.xlabel('Range of Tahun Lahir')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
#Distribution of Gapok
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['GAJI_POKOK'])
plt.title('Distribution of Gaji Pokok', fontsize = 20)
plt.xlabel('Range of Gaji Pokok')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
# karena belum adanya masa kerja dan sisa masa kerja PNS maka dari itu dibutuhkan field usia terlebih dahulu
# dengan asumsi dihitung sampai dengan tahun ini (tidak sampai ke bulan)
df['USIA'] = 2022 - df['TAHUN_LAHIR']

# %%
# count data dengan usia diatas BUP
usiaDiatasBup = df[df['USIA'] > df['BUP']]
len(usiaDiatasBup)
# Out:
# 2005

# %%
# dari data diatas masih ditemukan adanya Usia yang diatas BUP
# exclude data dengan usia diatas BUP
df = df[df['USIA'] < df['BUP']]

# %%
#Distribution of Usia
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['USIA'])
plt.title('Distribution of Usia', fontsize = 20)
plt.xlabel('Range of Usia')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
# Membuat atribut baru : SISA MASA KERJA
df['SISA_MASA_KERJA'] = df['BUP'] - df['USIA']

# %%
#Distribution of Sisa Masa Kerja
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['SISA_MASA_KERJA'])
plt.title('Distribution of Sisa Masa Kerja', fontsize = 20)
plt.xlabel('Range of Sisa Masa Kerja')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
# hitung tahun masuk dan masa kerja
df['TAHUN_MASUK'] = df['TMT_KERJA'].dt.year
df['MASA_KERJA'] = 2022 - df['TAHUN_MASUK']

# %%
#Distribution of Masa Kerja
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['MASA_KERJA'])
plt.title('Distribution of Masa Kerja', fontsize = 20)
plt.xlabel('Range of Masa Kerja')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
# karena dibutuhkan data Take Home Pay, dan yang dimiliki hanya field gaji pokok dan belum termasuk dengan tunjangan kinerja dan jabatan
# maka dari itu akan dihitung THP berdasarkan asumsi dari data kementerian keuangan

# create data tunjangan kinerja (tukin) from asumsi data kementerian keuangan
tukinDict = {
  "1A": 1287500 , "1B": 1377500, "1C": 1474000, "1D": 1577000, "2A": 1687500,
  "2B": 1805500, "2C": 1990000, "2D": 2089500, "3A": 2303500, "3B": 2539500,
  "3C": 3737000, "3D": 4229000, "4A": 6185000, "4B": 8350000, "4C": 9440000,
  "4D": 16270000, "4E": 23475000,
}

df['TUKIN'] = df['KODE_PANGKAT']
df['TUKIN'] = df['TUKIN'].map(tukinDict)

# karena data tujab tidak ada maka diasumsikan bahwa tukin = tujab
df['TUJAB'] = df['TUKIN']

# %%
#Distribution of Tukin
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['TUKIN'])
plt.title('Distribution of Tukin', fontsize = 20)
plt.xlabel('Range of Tukin')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
#Distribution of Tujab
plt.figure(figsize=(10, 6))
sns.set(style = 'whitegrid')
sns.distplot(df['TUJAB'])
plt.title('Distribution of Tujab', fontsize = 20)
plt.xlabel('Range of Tujab')
plt.ylabel('Count')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
df.head(2)
# Out:
#                          ID_PESERTA NAMA_STATUS_PEGAWAI NAMA_STATUS_KAWIN  \
# 0  D7F1E7316F97425C1700B06CFB291994       PEGAWAI TETAP             NIKAH
# 1  3562F7316F97425C1700B06CFB291994       PEGAWAI TETAP             NIKAH
#
#    TAHUN_LAHIR JENIS_KELAMIN  JMLISTRI  JMLANAK  GAJI_POKOK  TMT_KERJA  BUP  \
# 0         1965             P         1        0     4959460 1985-03-01   58
# 1         1973             P         1        2     4311936 2007-01-01   60
#
#                     NAMA_SATKER         DAERAH KODE_PANGKAT  USIA  \
# 0  PUSKESMAS PAMATANG SIDAMANIK  JAKARTA PUSAT           3D    57
# 1    BLUD PUSKESMAS PASAR KEMIS  JAKARTA TIMUR           4A    49
#
#    SISA_MASA_KERJA  TAHUN_MASUK  MASA_KERJA    TUKIN    TUJAB
# 0                1         1985          37  4229000  4229000
# 1               11         2007          15  6185000  6185000

# %%
# kita lihat sebaran data dalam bentuk histogram
df.hist(figsize=(16,16))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f70fa06b350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70fa018a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9fda0d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f70fa0116d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9fc7cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9f8b310>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9f42990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9ef8ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9ef8f10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9ebd650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9e2add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f70f9ded310>]],
#       dtype=object)

# %%
# Outlier Analysis of Gaji Pokok, Tukin and Tujab
attributes = ['GAJI_POKOK','TUKIN','TUJAB']
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data = df[attributes], orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
plt.ylabel("Range", fontweight = 'bold')
plt.xlabel("Attributes", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Attributes')

# %%
#Penghapusan data Outlier
# Removing (statistical) outliers for Gaji Pokok
Q1 = df.GAJI_POKOK.quantile(0.05)
Q3 = df.GAJI_POKOK.quantile(0.95)
IQR = Q3 - Q1
df = df[(df.GAJI_POKOK >= Q1 - 1.5*IQR) & (df.GAJI_POKOK <= Q3 + 1.5*IQR)]
# Removing (statistical) outliers for Tukin
Q1 = df.TUKIN.quantile(0.05)
Q3 = df.TUKIN.quantile(0.95)
IQR = Q3 - Q1
df = df[(df.TUKIN >= Q1 - 1.5*IQR) & (df.TUKIN <= Q3 + 1.5*IQR)]
# Removing (statistical) outliers for Tujab
Q1 = df.TUJAB.quantile(0.05)
Q3 = df.TUJAB.quantile(0.95)
IQR = Q3 - Q1
df = df[(df.TUJAB >= Q1 - 1.5*IQR) & (df.TUJAB <= Q3 + 1.5*IQR)]

# %% [markdown]
# Outlier : Data Tukin dan Tujab yang terdeteksi outlier dilakukan penghapusan dikarenakan populasi sedikit dan range data menjadi terlalu jauh

# %%
# hitung kembali THP 
df['THP'] = df['GAJI_POKOK'] + df['TUKIN'] + df['TUJAB']

# %%
# Outlier Analysis of GAJI_POKOK, Tukin and Tujab
attributes = ['GAJI_POKOK','TUKIN','TUJAB','THP']
plt.rcParams['figure.figsize'] = [10,8]
sns.boxplot(data = df[attributes], orient="v", palette="Set2" ,whis=1.5,saturation=1, width=0.7)
plt.title("Outliers Variable Distribution", fontsize = 14, fontweight = 'bold')
plt.ylabel("Range", fontweight = 'bold')
plt.xlabel("Attributes", fontweight = 'bold')
# Out:
# Text(0.5, 0, 'Attributes')

# %% [markdown]
# # Analisis Data Modeling (K-Means)
#
# ---

# %% [markdown]
# - Berdasarkan domain knowledge dalam hal potential market pembelian properti (apartemen), feature yang berpengaruh terhadap hal tersebut adalah SALARY (GAJI POKOK, TUKIN, TUJAB = THP) , TIME (SISA_MASA_KERJA), COST (JUMLAH_ISTRI, JUMLAH_ANAK)

# %%
# THP
df['QTHP'] = pd.cut(df['THP'], 5, labels=["low", "middle-low", "middle", "middle-high", "high"])

# %%
plt.figure(figsize=(5,3))
p = sns.countplot(x='QTHP', data=df)

# %%
df['QTHP'].value_counts()
# Out:
# low            82800
# middle-low     55187
# middle         32394
# middle-high    20647
# high            5361
# Name: QTHP, dtype: int64

# %%
# Usia
df['QUSIA'] = pd.cut(df['USIA'], 3, labels=["young", "middle-age", "older-adulthood"])

# %%
plt.figure(figsize=(10,3))
p = sns.countplot(x='QUSIA', data=df)

# %%
# Sisa Masa Kerja
df['QSISA'] = pd.cut(df['SISA_MASA_KERJA'], 3, labels=["short", "medium", "long"])

# %%
plt.figure(figsize=(10,3))
p = sns.countplot(x='QSISA', data=df)

# %%
# Masa Kerja
df['QMASAKERJA'] = pd.cut(df['MASA_KERJA'], 3, labels=["short", "medium", "long"])

# %%
plt.figure(figsize=(10,3))
p = sns.countplot(x='QMASAKERJA', data=df)

# %%
#Correlation Usia dengan THP
pd.crosstab(df['QUSIA'],df['QTHP']).plot(kind='bar',figsize=(15,5))

# %% [markdown]
# 1.   Di semua rentang usia populasi mayoritas memiliki THP low
# 2.   THP 'high' & 'middle-high hanya berada pada USIA 'middle age & older-adulthood'
#
# Hal ini sejalan dengan karakteristik hubungan antara THP dan USIA, semakin usianya besar semakin besar juga THPnya

# %%
#Correlation Masa Kerja dengan THP
pd.crosstab(df['QMASAKERJA'],df['QTHP']).plot(kind='bar',figsize=(15,5))

# %% [markdown]
# 1. PNS yang memiliki Masa Kerja 'short' didominasi memiliki THP 'low' dan tidak memiliki THP 'high'

# %%
#Correlation Masa Kerja dengan THP
pd.crosstab(df['QSISA'],df['QTHP']).plot(kind='bar',figsize=(15,5))

# %% [markdown]
# 1. THP 'high' dan middle-high ditemukan di sisa masa kerja short dan medium

# %%
# Rescaling Atribute
df_scaled = df[['JMLISTRI', 'JMLANAK', 'THP', 'USIA', 'MASA_KERJA','SISA_MASA_KERJA']]
# Instantiate
scaler = StandardScaler()
# fit_transform
df_scaled = scaler.fit_transform(df_scaled)
df_scaled.shape
# Out:
# (196389, 6)

# %%
df_scaled = pd.DataFrame(df_scaled)
df_scaled.columns = ['JMLISTRI', 'JMLANAK', 'THP', 'USIA', 'MASA_KERJA', 'SISA_MASA_KERJA']
df_scaled.head()
# Out:
#    JMLISTRI   JMLANAK       THP      USIA  MASA_KERJA  SISA_MASA_KERJA
# 0  0.543648 -1.360904  0.708521  1.536916    2.547731        -1.667858
# 1  0.543648  0.961084  1.694767  0.463437   -0.255577        -0.290448
# 2  0.543648  0.961084  0.348989 -0.744226   -0.510424         0.673738
# 3  0.543648 -0.199910 -0.834704 -0.475857   -0.128154         0.398256
# 4 -1.839426 -1.360904  0.306539  1.536916   -0.637847        -1.392376

# %% [markdown]
# # PCA
#
# ---

# %%
pca = PCA()
pca.fit(df_scaled)
# Out:
# PCA()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.48273245, 0.24643184, 0.14424567, 0.06416293, 0.0600156 ,
#        0.0024115 ])

# %%
plt.figure(figsize = (10,8))
plt.plot(range(1,7), pca.explained_variance_ratio_.cumsum(), marker = 'o', linestyle = '--')
plt.title('Explained Variance by Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
# Out:
# Text(0, 0.5, 'Cumulative Explained Variance')

# %% [markdown]
# **80% dengan 3 component**

# %%
pca = PCA(n_components = 3)

# %%
pca.fit(df_scaled)
# Out:
# PCA(n_components=3)

# %%
pca.transform(df_scaled)
# Out:
# array([[ 3.33766971, -0.49899118, -0.13461536],
#        [ 0.50159637, -1.21711411,  1.21283351],
#        [-1.21498113, -0.67089244,  0.76579648],
#        ...,
#        [-1.16201933, -0.70977827,  0.44271668],
#        [-3.4835845 ,  0.92585814,  0.28344677],
#        [-3.14665275,  0.82326612,  0.42291045]])

# %%
scores_pca = pca.transform(df_scaled)
scores_pca
# Out:
# array([[ 3.33766971, -0.49899118, -0.13461536],
#        [ 0.50159637, -1.21711411,  1.21283351],
#        [-1.21498113, -0.67089244,  0.76579648],
#        ...,
#        [-1.16201933, -0.70977827,  0.44271668],
#        [-3.4835845 ,  0.92585814,  0.28344677],
#        [-3.14665275,  0.82326612,  0.42291045]])

# %% [markdown]
# **K-MEANS with PCA**
#
# ---

# %%
wcss = []
for i in range (1,11):
    kmeans_pca = KMeans(n_clusters=i, init='k-means++', random_state=22)
    kmeans_pca.fit(scores_pca)
    wcss.append(kmeans_pca.inertia_)

# %%
plt.figure(figsize= (10,8))
plt.plot(range(1,11), wcss, marker = 'o', linestyle = '--')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.title('K-Means with PCA Clustering')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
kmeans_pca = KMeans(n_clusters = 3, init = 'k-means++', random_state=22)

# %%
kmeans_pca.fit(scores_pca)
# Out:
# KMeans(n_clusters=3, random_state=22)

# %% [markdown]
# **K-Means clustering with PCA Result**
#
# ---

# %%
df_segm_pca_kmeans = pd.concat([df_scaled.reset_index(drop=True), pd.DataFrame(scores_pca)], axis=1)
df_segm_pca_kmeans.columns.values[-3: ] = ['Components 1', 'Components 2', 'Components 3']
df_segm_pca_kmeans['Segment K-Means PCA'] = kmeans_pca.labels_
df_segm_pca_kmeans.head()
# Out:
#    JMLISTRI   JMLANAK       THP      USIA  MASA_KERJA  SISA_MASA_KERJA  \
# 0  0.543648 -1.360904  0.708521  1.536916    2.547731        -1.667858
# 1  0.543648  0.961084  1.694767  0.463437   -0.255577        -0.290448
# 2  0.543648  0.961084  0.348989 -0.744226   -0.510424         0.673738
# 3  0.543648 -0.199910 -0.834704 -0.475857   -0.128154         0.398256
# 4 -1.839426 -1.360904  0.306539  1.536916   -0.637847        -1.392376
#
#    Components 1  Components 2  Components 3  Segment K-Means PCA
# 0      3.337670     -0.498991     -0.134615                    0
# 1      0.501596     -1.217114      1.212834                    0
# 2     -1.214981     -0.670892      0.765796                    1
# 3     -0.877320      0.008845     -0.469247                    1
# 4      2.055333      1.630612     -0.983642                    2

# %%
kmeans_ex = KMeans(n_clusters=3).fit(df_scaled)
label_ex = kmeans_ex.labels_
print(label_ex)
# Out:
# [2 2 0 ... 0 0 0]

# %%
df_segm_pca_kmeans['Segment'] = df_segm_pca_kmeans['Segment K-Means PCA'].map({0:'first',1:'Second',3:'Third'})

# %%
df['Cluster'] = df_segm_pca_kmeans['Segment K-Means PCA']

# %%
df['Cluster'].value_counts()
# Out:
# 1.0    76971
# 0.0    67394
# 2.0    39316
# Name: Cluster, dtype: int64

# %%
x_axis = df['THP']
y_axis = df['USIA']
plt.figure(figsize=(10,8))
sns.scatterplot(x_axis, y_axis, hue = df_segm_pca_kmeans['Segment K-Means PCA'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
x_axis = df['THP']
y_axis = df['MASA_KERJA']
plt.figure(figsize=(10,8))
sns.scatterplot(x_axis, y_axis, hue = df_segm_pca_kmeans['Segment K-Means PCA'])
plt.title('Clusters by PCA Components')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Setelah dilakukan segmentasi menggunakan K-Means dengan 3 cluster dengan menggunakan data original ternyata tidak ditemukan keunikan dari masing-masing cluster sehingga akan dilakukan modelling menggunaka roled based analysis

# %% [markdown]
# # Analisis Data Role Based
#
# ---

# %%
new_df = df[['NAMA_STATUS_KAWIN','JENIS_KELAMIN','JMLISTRI','JMLANAK','THP','SISA_MASA_KERJA','USIA']]

# %% [markdown]
# **THP Segmentation**
#
# ---

# %%
# Calculate THP
new_df['THP'].quantile([0.20, 0.40, 0.60, 0.80])
# Out:
# 0.2     8184984.0
# 0.4     9059480.0
# 0.6    11443024.0
# 0.8    12859540.0
# Name: THP, dtype: float64

# %%
# THP segmentation using quartile
new_df['THP_GROUP'] = pd.cut(df['THP'], 5, labels=[1, 2, 3, 4, 5]) 
new_df['THP_GROUP'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1    82800
# 2    55187
# 3    32394
# 4    20647
# 5     5361
# Name: THP_GROUP, dtype: int64

# %%
# Group by the THP segments
df_T = new_df.groupby(['THP_GROUP']).agg(TotalCustomer=('THP_GROUP', 'count')).reset_index(drop=False)

# Rename the T segments
df_T.loc[df_T['THP_GROUP'] == 1, 'T_group'] = 'Low'
df_T.loc[df_T['THP_GROUP'] == 2, 'T_group'] = 'Medium-Low'
df_T.loc[df_T['THP_GROUP'] == 3, 'T_group'] = 'Medium'
df_T.loc[df_T['THP_GROUP'] == 4, 'T_group'] = 'Medium-High'
df_T.loc[df_T['THP_GROUP'] == 5, 'T_group'] = 'High'

# Calculate the F_group percentage
df_T['T_Percentage'] = round(df_T['TotalCustomer']/df_T['TotalCustomer'].sum() * 100, 2)

# Reorder the columns
df_T = df_T[['THP_GROUP', 'T_group', 'TotalCustomer', 'T_Percentage']]
df_T
# Out:
#   THP_GROUP      T_group  TotalCustomer  T_Percentage
# 0         1          Low          82800         42.16
# 1         2   Medium-Low          55187         28.10
# 2         3       Medium          32394         16.49
# 3         4  Medium-High          20647         10.51
# 4         5         High           5361          2.73

# %% [markdown]
# **Notes:**
#
# THP in Rupiah (Rp)
#
# 1. *High:* THP lebih besar dari 12.859.541. `(> 12,8 Jt)`
# 2. *Medium-High:* THP antara 11.443.025 dan 12.859.540. `(11,4 - 12,8 Jt)`
# 3. *Medium:* THP is antara 9.059.481 dan 11.443.024. `(9 - 11,4 Jt)`
# 4. *Medium-Low:* THP is antara 8.184.984 dan 9.059.480. `(8 - 9 Jt)`
# 5. *Low:* THP kurang dari 8.184.983. `(< 8 Jt)`

# %%
# Distribution of thp group segmentation
plt.figure(figsize=(10, 5))
sns.barplot(y='T_group', x='TotalCustomer', data=df_T, palette='viridis_r')
plt.title('Distribution of THP Segmentation', fontsize=16)
plt.xlabel('Number of Customers', fontsize=12)
plt.ylabel('THP', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10);

# %% [markdown]
# **Key Takeaways**
#
# **Berdasarkan grafik di atas, sebagian besar data berada berada di segmen 'Low' (42.16%), maka dapat dikatakan bahwa PNS yang paling banyak adalah PNS yang memiliki gaji dibawah 8 Jt.**

# %% [markdown]
# **Sisa Masa Kerja Segmentation**
#
# ---

# %%
new_df['SISA_MASA_KERJA'].quantile([0.25, 0.50, 0.75])
# Out:
# 0.25     7.0
# 0.50    13.0
# 0.75    19.0
# Name: SISA_MASA_KERJA, dtype: float64

# %%
# Sisa Masa Kerja segmentation using quartile
new_df['SISA_MASA_KERJA_GROUP'] = pd.cut(new_df['SISA_MASA_KERJA'], 3, labels=[1, 2, 3], duplicates='drop')
new_df['SISA_MASA_KERJA_GROUP'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1    101800
# 2     86801
# 3      7788
# Name: SISA_MASA_KERJA_GROUP, dtype: int64

# %%
# Group by the M segments
df_S = new_df.groupby(['SISA_MASA_KERJA_GROUP']).agg(TotalCustomer=('SISA_MASA_KERJA_GROUP', 'count')).reset_index(drop=False)

# Rename the F segments
df_S.loc[df_S['SISA_MASA_KERJA_GROUP'] == 1, 'S_group'] = 'Short'
df_S.loc[df_S['SISA_MASA_KERJA_GROUP'] == 2, 'S_group'] = 'Middle'
df_S.loc[df_S['SISA_MASA_KERJA_GROUP'] == 3, 'S_group'] = 'Long'

# Calculate the F_group percentage
df_S['S_Percentage'] = round(df_S['TotalCustomer']/df_S['TotalCustomer'].sum()*100, 2)

# Reorder the columns
df_S = df_S[['SISA_MASA_KERJA_GROUP', 'S_group', 'TotalCustomer', 'S_Percentage']]
df_S
# Out:
#   SISA_MASA_KERJA_GROUP S_group  TotalCustomer  S_Percentage
# 0                     1   Short         101800         51.84
# 1                     2  Middle          86801         44.20
# 2                     3    Long           7788          3.97

# %% [markdown]
# **Notes:**
#
# SISA_MASA_KERJA (Tahun)
#
# 1. *Short:* SISA_MASA_KERJA kurang dari 7 tahun. `(> 7 tahun)`
# 2. *Middle:* SISA_MASA_KERJA antara 13 - 19 tahun. `(11 - 19 tahun)`
# 3. *Long:* SISA_MASA_KERJA diatas 19 Tahun. `(< 19 tahun)`

# %%
# Distribution of recency segmentation
plt.figure(figsize=(10, 5))
sns.barplot(y='S_group', x='TotalCustomer', data=df_S, palette='viridis_r')
plt.title('Distribution of SISA_MASA_KERJA Segmentation', fontsize=16)
plt.ylabel('SISA_MASA_KERJA', fontsize=12)
plt.xlabel('Number of Customers', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10);

# %% [markdown]
# **Key Takeaways**
#
# **Berdasarkan grafik di atas, dapat dilihat bahwa sebagian besar data berada di segmen 'Short' (51.84%) dimana sisa masa kerja dibawah 7 tahun. namun, selisih antara sisa masa kerja 'short' dan 'middle' juga tidak terlalu jauh.

# %% [markdown]
# **Tanggungan Segmentation**
#
# ---

# %% [markdown]
# diasumsikan bahwa tanggungan biaya hidup berbanding lurus dengan jumlah istri dan anak yang dimiliki, maka dari itu tanggungan biaya hidup akan didefinisikan menggunakan variabel jumlah istri + jumlah anak

# %%
new_df['JUMLAH_TANGGUNGAN'] = new_df['JMLISTRI'] + new_df['JMLANAK']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df['JUMLAH_TANGGUNGAN'].quantile([0.25, 0.50, 0.75])
# Out:
# 0.25    1.0
# 0.50    2.0
# 0.75    3.0
# Name: JUMLAH_TANGGUNGAN, dtype: float64

# %%
# Jumlah tanggungan segmentation using quartile
new_df['TG'] = pd.cut(new_df['JUMLAH_TANGGUNGAN'], 3, labels=[3, 2, 1], duplicates='drop')
new_df['TG'].value_counts()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 1    89925
# 3    62082
# 2    44382
# Name: TG, dtype: int64

# %%
# Group by the M segments
df_TG = new_df.groupby(['TG']).agg(TotalCustomer=('TG', 'count')).reset_index(drop=False)

# Rename the F segments
df_TG.loc[df_TG['TG'] == 1, 'TG_group'] = 'Low'
df_TG.loc[df_TG['TG'] == 2, 'TG_group'] = 'Medium'
df_TG.loc[df_TG['TG'] == 3, 'TG_group'] = 'High'

# Calculate the F_group percentage
df_TG['TG_Percentage'] = round(df_TG['TotalCustomer']/df_TG['TotalCustomer'].sum()*100, 2)

# Reorder the columns
df_TG = df_TG[['TG', 'TG_group', 'TotalCustomer', 'TG_Percentage']]
df_TG
# Out:
#   TG TG_group  TotalCustomer  TG_Percentage
# 0  3     High          62082          31.61
# 1  2   Medium          44382          22.60
# 2  1      Low          89925          45.79

# %% [markdown]
# **Notes:**
#
# **JUMLAH_TANGGUNGAN**
#
# 1. *Low:* JUMLAH_TANGGUNGAN dibawah 1. `(1)`
# 2. *Medium:* JUMLAH_TANGGUNGAN lebih dari 1 sampai dengan kurang dari 3. `(1-3)`
# 3. *High:* JUMLAH_TANGGUNGAN sama dengan 3. `(3)`

# %%
# Distribution of jumlah tanggungan segmentation
plt.figure(figsize=(10, 5))
sns.barplot(y='TG_group', x='TotalCustomer', data=df_TG, palette='viridis_r')
plt.title('Distribution of JUMLAH_TANGGUNGAN Segmentation', fontsize=16)
plt.ylabel('JUMLAH_TANGGUNGAN', fontsize=12)
plt.xlabel('Number of Customers', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10);

# %% [markdown]
# **Key Takeaways**
#
# **Berdasarkan grafik di atas, sebagian besar data berada pada segmen 'High' (45.79%), dapat dikatakan bahwa sebagian besar PNS  memiliki jumlah tanggungan sama dengan 3**

# %%
# Calculate Segment and Score
new_df['Segment'] = new_df['THP_GROUP'].astype('string') + new_df['SISA_MASA_KERJA_GROUP'].astype('string') + new_df['TG'].astype('string')
new_df['Score'] = new_df['THP_GROUP'].astype('int') + new_df['SISA_MASA_KERJA_GROUP'].astype('int') + new_df['TG'].astype('int') 
new_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        NAMA_STATUS_KAWIN JENIS_KELAMIN  JMLISTRI  JMLANAK       THP  \
# 0                  NIKAH             P         1        0  13417460
# 1                  NIKAH             P         1        2  16681936
# 2                  NIKAH             P         1        2  12227410
# 3                 LAJANG             P         1        1   8309384
# 4                 LAJANG             L         0        0  12086900
# ...                  ...           ...       ...      ...       ...
# 210211             NIKAH             P         1        2   8886942
# 210212             NIKAH             L         1        2   7935914
# 210213             NIKAH             L         1        2  11321842
# 210214            LAJANG             L         1        1   7680840
# 210215             NIKAH             L         1        1   8383672
#
#         SISA_MASA_KERJA  USIA THP_GROUP SISA_MASA_KERJA_GROUP  \
# 0                     1    57         3                     1
# 1                    11    49         4                     1
# 2                    18    40         2                     2
# 3                    16    42         1                     2
# 4                     3    57         2                     1
# ...                 ...   ...       ...                   ...
# 210211               14    44         1                     2
# 210212               14    44         1                     2
# 210213               17    41         2                     2
# 210214               29    29         1                     3
# 210215               28    30         1                     3
#
#         JUMLAH_TANGGUNGAN TG Segment  Score
# 0                       1  3     313      7
# 1                       3  1     411      6
# 2                       3  1     221      5
# 3                       2  2     122      5
# 4                       0  3     213      6
# ...                   ... ..     ...    ...
# 210211                  3  1     121      4
# 210212                  3  1     121      4
# 210213                  3  1     221      5
# 210214                  2  2     132      6
# 210215                  2  2     132      6
#
# [196389 rows x 13 columns]

# %% [markdown]
# Semakin tinggi Skor, semakin berharga pelanggan. Kombinasi terbaik adalah di mana Segmen adalah `**533**` sehingga Skornya menjadi 11.

# %%
# Grouping customers by Score
new_df.groupby('Score').agg({
    'THP':'mean', 
    'SISA_MASA_KERJA':'mean', 
    'JUMLAH_TANGGUNGAN':['mean', 'count']}).round(2)
# Out:
#                THP SISA_MASA_KERJA JUMLAH_TANGGUNGAN
#               mean            mean              mean  count
# Score
# 3       8173641.36            8.68              3.00  14379
# 4       8737421.06           14.14              2.78  42072
# 5      10289419.07           12.95              2.15  51741
# 6      11606231.57           14.40              1.67  43238
# 7      12991848.29           14.30              0.99  30369
# 8      16935846.97            8.57              0.69  10185
# 9      19966515.42            8.89              0.25   4222
# 10     20679575.88           17.07              0.26    182
# 11     21173150.00           28.00              1.00      1

# %% [markdown]
# Berdasarkan hasil di atas, kami dapat membagi pelanggan menjadi tiga segmen utama, yaitu:
#
# |Segment|Score|
# |---|---|
# |Bronze|3-4|
# |Silver|5-7|
# |Gold|8-11|

# %%
# Customer segmentation
def customer_segmentation(i):
    if i <= 4:
        return 'Bronze'
    elif i <=7:
        return 'Silver'
    else:
        return 'Gold'

new_df['CustomerSegment'] = new_df['Score'].apply(customer_segmentation)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Customer segmentation mean of each segment
cust_agg = new_df.groupby('CustomerSegment').agg({
    'THP' : 'mean',
    'SISA_MASA_KERJA' : 'mean',
    'JUMLAH_TANGGUNGAN' : 'mean',
    'Segment' : 'count'
}).round(2).sort_values(by='Segment')

cust_agg
# Out:
#                          THP  SISA_MASA_KERJA  JUMLAH_TANGGUNGAN  Segment
# CustomerSegment
# Gold             17859841.36             8.77               0.56    14590
# Bronze            8593817.08            12.75               2.84    56451
# Silver           11398383.01            13.78               1.70   125348

# %%
# Distribution of customer segmentation
plt.figure(figsize=(10, 4))
sns.countplot(y='CustomerSegment', data=new_df, palette='viridis_r', order = cust_agg['Segment'].index)
plt.title('Distribution of Customer Segmentation', fontsize=16)
plt.xlabel('Number of Customers', fontsize=12)
plt.ylabel('Segment', fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10);

# %% [markdown]
# 1.   Gold
# *   PNS yang memiliki THP tinggi, dengan sisa masa kerja relatif pendek dan dengan jumlah tanggungan yang kecil
# 2.   Silver
# *   PNS yang memiliki THP sedang (medium, medium-high) dengan sisa masa kerja yang relatif panjang dan jumlah tanggungan yang sedang
# 3.   Bronze
# *   PNS yang memiliki THP kecil dengan sisa masa kerja yang relatif panjang dan jumlah tanggungan yang besar

# %% [markdown]
# DATA PRICE LIST APARTMENT
#
#
# ---

# %% [markdown]
# |Segment|Score|
# |---|---|
# |𝙎𝙩𝙪𝙙𝙞𝙤|mulai Rp400.528.105,- Jutaan|
# |𝟏𝘽𝙍|mulai Rp595.903.625,-Jutaan|
# |𝟏𝘽𝙍|Sudut Hug mulai Rp688.367.425,-Jutaan|

# %% [markdown]
# 1. Validasi potensi market yang ada pada daerah pembangunan dan daerah sekitar yang masih masuk dalam wilayah target market
# > dari analisis yang sudah terbentuk, dapat dikatakan bahwa segmentasi yang terbentuk mayoritas masuk dalam kelompok `'silver'` dimana memiliki THP yang relatif tinggi `(9-12,8 jt)`, masa kerja yang relatif panjang yaitu diantara `11 - 19 tahun`, dengan tanggungan sedang `(antara 1-3 orang)`. kesimpulan ini dapat dijadikan landasan opini bahwa pembangunan Apartemen di daerah Tangerang cocok dengan harga yang ditawarkan.
# 2. Apakah Target market memiliki daya beli yang sejalan dengan harga dari apartemen yang akan dibangun
# > - dari analisis yang sudah terbentuk, dikatakan bahwa mayoritas masuk ke dalam kelompok `'silver' `dimana memiliki `THP +- 11 Jt`. dan sisa masa kerja yang cukup panjang antara `11-19 tahun`.
# > - jika kita hitung dengan rata-rata harga apartemen adalah `500 jt` dan tenor rata-rata sesuai dengan `sisa masa kerja adalah 15 tahun`, serta bunga KPR rata-rata adalah `+- 8.5 %`. dengan `DP minimal +-30%`. maka didapatkan cicilan per bulan adalah sebesar `+- Rp3.446.588`.
# >- yang berarti rasio kreditnya menjadi. `(3.446.588 / 11.000.000) * 100% = 30.9 %`. nilai tersebut masih layak jika mengacu ke nilai maksimal dari rasio kredit pinjaman yaitu `+- 30.xx %`.
#
# 3. Menemukan potensi customer segmentation yang nantinya akan dijadikan dasar rencana strategis pemasaran oleh tim bisnis:
# >- untuk customer segemen `'Silver'` adalah target market utama dari pemasaran dan penjualan apartemen aspena residence.
# >- untuk customer segmen yang `'Gold'` dengan `THP yang tinggi rata-rata +-17 Jt` dan `sisa_masa kerja yang relatif pendek +- 8 tahun` dan jumlah_tanggungan yang relatif kecil. bisa diasumsikan segmentasi ini adalah orang-orang yang memiliki kemampuan financial lebih dibandingkan segmen lain, maka dari itu bisa dilakukan pendekatan penjualan hunian dengan tujuan sebagai produk investasi.
# >- untuk customer segmen `'Bronze'` diasumsikan menurut data adalah segmen yang memiliki kemampuan finansial lebih rendah dari pada yang lain, sehingga perlu diberikan treatmen khusus misalkan, diskon referal + pembiayaan kredit yang lebih fleksibel.
